# %%
# !pip install -q tweepy

# %%
import tweepy

CONSUMER_KEY = "Q5pIyehqfmXSkXlbjD83kury7"
CONSUMER_SECRET = "LU320185YgHJ2dOcfyMOYE4X7SWCHoUXk1XzUQVq0zWN9zq0xn"
OAUTH_TOKEN = "1179779701977411584-Hkh7jyJCEJ2w9ySs232YszIG7QKBtO"
OAUTH_TOKEN_SECRET = "J27rOctYSW5E1mZYF2no78d39mzLTH5TKq5C8l4Xj8tCJ"


auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
api = tweepy.API(auth)

tweet = api.get_status('839880162586071040')
print(tweet.text)
# Out:
# RT @GemmaAnneStyles: Happy #womensday to all my sassy women, classy women, nasty women 💋👧🏾💖👩🏼‍🔬👄👵🏼 my fine women, alive women, gonna fight…

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from itertools import repeat
import csv
import time

with open('/content/gdrive/My Drive/Group 12 - IRE monsoon Project/benevolent_sexist.tsv','rt') as tsvin, open('/content/gdrive/My Drive/Group 12 - IRE monsoon Project/new.csv', 'w+') as csvout:
    tsvin = csv.reader(tsvin, delimiter='\t')
    csvout = csv.writer(csvout)

    for row in tsvin:
      print(row[0])
      try:
        tweet = api.get_status(row[0])
        #print(tweet.text)
        csvout.writerows(tweet.text)
        time.sleep(300/1000)
      except tweepy.TweepError as e:
        print(e)
        #print (e)
        #print (type(e))
        #print (e.__dict__)
        #print (e.reason)
        #print (type(e.reason))
# Out:
# 839880162586071040
# 839630746625142784
# [{'code': 144, 'message': 'No status found with that ID.'}]
# 839630739335495681
# [{'code': 144, 'message': 'No status found with that ID.'}]
# 839665182985097216
# 839765815494795264
# [{'code': 63, 'message': 'User has been suspended.'}]
# 839584192715337728
# [{'code': 144, 'message': 'No status found with that ID.'}]
# 839688595460014080
# [{'code': 63, 'message': 'User has been suspended.'}]
# 839581330371407883
# [{'code': 63, 'message': 'User has been suspended.'}]
# 839805807717937153
# [{'code': 144, 'message': 'No status found with that ID.'}]
# 839890972477575168
# 839630815109619712
# [{'code': 144, 'message': 'No status found with that ID.'}]
# 839630801746739202
# [{'code': 144, 'message': 'No status found with that ID.'}]
# 839695799768379392
# [{'code': 63, 'message': 'User has been suspended.'}]
# 839677985284202496
# 839505603399680000
# [{'code': 63, 'message': 'User has been suspended.'}]
# 839752088859062272
# ...

# %%
# !pip install python-twitter
# Out:
# ...
#      |████████████████████████████████| 71kB 2.3MB/s
# ...

# %%
import twitter
api = twitter.Api(consumer_key=CONSUMER_KEY,
                  consumer_secret=CONSUMER_SECRET,
                  access_token_key=OAUTH_TOKEN,
                  access_token_secret=OAUTH_TOKEN_SECRET,
                  sleep_on_rate_limit=True)
